# %%
# --- built in ---
import os
import sys
import time
import math
import logging
import functools
import matplotlib.pyplot as plt

# --- 3rd party ---
import numpy as np
import torch
from torch import nn
import random

# --- owner's ---
import utils as utl
from model import Energy, ToyMLP
import train as trn

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# show distribution
train_dataset = utl.sample_2d('2spirals',1000000)
rng = [[-4, 4], [-4, 4]]
plt.hist2d(train_dataset[:,0].numpy(), train_dataset[:, 1].numpy(), range=rng, bins=500, cmap=plt.cm.viridis)
plt.title('Distribution being modelled')
plt.show()

# %%
# Train model
train_dataset = train_dataset[torch.randperm(train_dataset.size(0))]
model = Energy(
    net = ToyMLP()
)
trainer = trn.Trainer(
    model,
    trained=True,
    learning_rate = 1e-3,
    n_slices = 1,
    loss_type='ebm',
    batch_size=100,
    percent_model_sample=0.95,
    alpha=0.001
).learn(
    train_dataset = train_dataset,
    n_epochs = 1,
    batch_size = 100
)
# save model
trainer.model.save('ebm')

# %%
ini_samples = torch.rand(100000, 2) * 6 - 3
model = Energy(
        net = ToyMLP()
    )
model.load('ebm')
samples = utl.langevin_dynamics(
        lambda x: model.score(x),
        ini_samples,
        eps=0.01,
        n_steps=100
    ).detach().cpu().numpy()
rng = [[-4, 4], [-4, 4]]
plt.hist2d(samples[:,0], samples[:, 1], range=rng, bins=500, cmap=plt.cm.viridis)
plt.axis(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 model.load('ebm')
#       6 score_fn = lambda x: model.score(x)
# ----> 7 samples = utl.langevin_dynamics(
#       8         score_fn,
#       9         ini_samples,
#      10         eps=0.01,
#      11         n_steps=100
#      12     ).detach().cpu().numpy()
#      13 rng = [[-4, 4], [-4, 4]]
#      14 plt.hist2d(samples[:,0], samples[:, 1], range=rng, bins=500, cmap=plt.cm.viridis)
#
# File c:\Users\adity\Documents\pyTorch_tutorial\ld\utils.py:61, in langevin_dynamics(score_fn, x, eps, n_steps)
#      51 """Langevin dynamics
#      52
#      53 Args:
#    (...)
#      58     n_steps (int, optional): number of steps. Defaults to 1000.
#      59 """
#      60 for i in range(n_steps):
# ---> 61     x = x + eps/2. * score_fn(x).detach()
#      62     x = x + torch.randn_like(x) * np.sqrt(eps)
#      63 return x
#
# Cell In[9], line 6, in <lambda>(x)
#       2 model = Energy(
#       3         net = ToyMLP()
#       4     )
#       5 model.load('ebm')
# ----> 6 score_fn = lambda x: model.score(x)
#       7 samples = utl.langevin_dynamics(
#       8         score_fn,
#       9         ini_samples,
#      10         eps=0.01,
#      11         n_steps=100
#      12     ).detach().cpu().numpy()
#      13 rng = [[-4, 4], [-4, 4]]
#
# File c:\Users\adity\Documents\pyTorch_tutorial\ld\model.py:89, in Energy.score(self, x, sigma)
#      87 def score(self, x, sigma=None):
#      88     x = x.requires_grad_()
# ---> 89     logp = -self.net(x).sum()
#      90     return torch.autograd.grad(logp, x, create_graph=True)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\adity\Documents\pyTorch_tutorial\ld\model.py:67, in ToyMLP.forward(self, x)
#      66 def forward(self, x):
# ---> 67     return self.net(x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\adity\Documents\pyTorch_tutorial\ld\model.py:27, in Swish.forward(self, x)
#      25 def forward(self, x):
#      26     if len(x.size()) == 2:
# ---> 27         return x * torch.sigmoid(self.beta[None, :] * x)
#      28     else:
#      29         return x * torch.sigmoid(self.beta[None, :, None, None] * x)
#
# KeyboardInterrupt:

# %%
model = Energy(
        net = ToyMLP()
    )
model.load('ebm')
out = utl.sample_energy_field(
    model,
    range_lim=4,
    grid_size=1000,
    device='cpu'
)
plt.imshow(out)
plt.axis(False)
# Out:
# (-0.5, 999.5, 999.5, -0.5)
